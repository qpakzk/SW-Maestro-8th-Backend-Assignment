# %% [markdown]
# # 8기 과제 - 딥러닝 기반 상품 카테고리 자동 분류 서버

# %% [markdown]
# ## 과제 개요
# * 출제자 : 남상협 멘토 (justin@buzzni.com) / 버즈니 (http://buzzni.com) 대표
# * 배경 : 카테고리 분류 엔진은 실제로 많은 서비스에서 사용되는 중요한 기계학습 기술이다. 본 과제의 주제는 버즈니 개발 인턴이자 마에스트로 6기 멘티가 아래와 나와 있는 기본 분류 모델을 기반으로 deep learning 기반의 feature 를 더해서 고도화된 분류 엔진을 만들어서 2016 한국 정보과학회 논문으로도 제출 했던 주제이다. 기계학습에 대한 학습과, 실용성 두가지 측면에서 모두 도움이 될 것으로 보인다.

# %% [markdown]
# ## 과제 목표
# * 입력 : 상품명, 상품 이미지
# * 출력 : 카테고리
# * 목표 : 가장 높은 정확도로 분류를 하는 분류 엔진을 개발

# %% [markdown]
# ## 평가 항목
# * 성능평가 (100%)
#
# ## 제출 항목
# * 채점 서버에 자신이 분류한 class id 리스트를 파라미터로 넣어서 호출한다.
# * name - 자신의 이름을 넣는다. 실제 점수판에는 공개가 안됨, 추후 평가시에 일치하는 이름의 멘티 점수로 사용함. 요청한 평가 중에서 가장 높은 점수의 평가 점수로 업데이트됨.
# * nickname - 점수판에 공개되는 이름, 자신의 이름으로 해도 되고, 닉네임으로 해도 됨. 구분을 위해서 사용하는 feature(text, textimage) 와 알고리즘 (svm, cnn) 등을 닉네임 뒤에 붙여준다.
# * pred_list - 분류한 카테고리 id 리스트를 , 로 묶은 데이터
# * 평가 점수가 반환된다. - precision, 높을 수록 좋다. 두가지 방법 각각 50%씩 점수 반영
# * mode - 'test' 로 호출하면 웹으로 순위가 공개되는 테스트 평가를 수행하고 결과 점수가 반환된다. 해당 결과 점수는 http://eval.buzzni.net:20002/score 에서 확인 가능함. 실제 성적 평가는 'eval' 로 평가용 데이터로 호출하면 된다. 이때는 점수가 반환되거나, 웹 점수 보드에도 나오지 않는다.
# * 너무 자주 평가를 요청하기 보다, 가급적 자체적으로 평가 해서, 괜찮게 나올때 요청하길 권장
# ```python
# import requests
# name='test1'
# nickname='test1_text_svm'
# mode='test' #'eval' 을 실제 성적 평가용. 분류 점수 반환 안됨.
# param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list)),
#          'name':name,'nickname':nickname,"mode":mode}
# d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
# print (d.json())
#          ```

# %% [markdown]
# ## 성능 향상 포인트
# * http://localhost:8000/notebooks/maestro8_deeplearning_product_classifier.ipynb 이 노트북에 있는 딥러닝 기반의 분류기로 분류할 경우에 더 높은 성능을 낼 수 있어서 유리함
# * 아래의 방법들은 하나의 예이고, 아래에 나와 있지 않은 다양한 방법들도 가능함.
# * 전처리
#  * 오픈된 형태소 분석기(예 - konlpy) 를 써서, 단어 띄어쓰기를 의미 단위로 띄어서 학습하기
#  * bigram, unigram, trigram 등 단어 feature 를 더 다양하게 추가하기
# * 딥러닝
#  * embedding weight 를 random 이 아닌 학습된 값을 사용하기 (https://radimrehurek.com/gensim/models/word2vec.html)
#  * 이미지 feature 를 CNN으로 추출할때 더 성능이 좋은 모델 사용하기 (예제로 준 데이터는 mobilenet 으로 성능보다 속도 위주로 된 모델)
#  * 다양한 파라미터(hyper parameter) 로 실험 해보기
# * 피쳐 조합
#  * 이미지 feature 와 text feature 를 합치는 부분 잘하기

# %% [markdown]
# ## 평가 점수 서버
# * 현재 평가 순위를 json 형태로 반환한다.
# * 여러번 호출했을때는 가장 높은 점수로 업데이트 한다.
#  * http://eval.buzzni.net:20002/score
# * 실제 점수는

# %%
import sys
from sklearn.externals import  joblib
from sklearn.grid_search import GridSearchCV
from sklearn.svm import  LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import  TfidfVectorizer,CountVectorizer
import os
import numpy as np
import string
# from keras import backend
# from keras.layers import Dense, Input, Lambda, LSTM, TimeDistributed
# from keras.layers.merge import concatenate
# from keras.layers.embeddings import Embedding
# from keras.models import Model
from konlpy.tag import Twitter, Kkma
# Out:
# /usr/local/lib/python3.4/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.4/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def extract(data):
    kkma = Kkma()
    twit = Twitter()
    line_list = []
    for datum in data:
        word_str = datum[1]
        word_list = kkma.nouns(word_str)
        word_list2 = twit.nouns(word_str)
        line_word = word_list + word_list2
        line_str = " ".join(line_word)
        line_list.append(line_str)
    return line_list

# %%
# twit.nouns(X_train[0][1])

# %% [markdown]
# ### 파일에서 학습 데이터를 읽는다.

# %%
import json

# %%
x_text_list = []
y_text_list = []
enc = sys.getdefaultencoding()
with open("refined_category_dataset.dat",encoding=enc) as fin:
    for line in fin.readlines():
#         print (line)
        info = json.loads(line.strip())
        x_text_list.append((info['pid'],info['name']))
        y_text_list.append(info['cate'])

# %%
# joblib.dump(y_name_id_dict,"y_name_id_dict.dat")

# %% [markdown]
# ### text 형식으로 되어 있는 카테고리 명을 숫자 id 형태로 변환한다.

# %%
y_name_id_dict = joblib.load("y_name_id_dict.dat")

# %%
print(y_name_id_dict)
# Out:
# {'여행/e쿠폰': 15, '뷰티': 0, '의류': 2, '취미': 5, '생필품/주방': 13, '식품': 6, '출산/육아': 16, '디지털': 10, '반려동물': 4, '자동차/공구': 1, '컴퓨터': 3, '잡화': 14, '건강': 7, '가전': 12, '스포츠/레저': 9, '도서/문구': 8, '가구/인테리어': 11}

# %%
# y_name_set = set(y_text_list)
# y_name_id_dict = dict(zip(y_name_set, range(len(y_name_set))))
# print(y_name_id_dict.items())
# y_id_name_dict = dict(zip(range(len(y_name_set)),y_name_set))
y_id_list = [y_name_id_dict[x] for x in y_text_list]

# %% [markdown]
# ### text 형태로 되어 있는 상품명을 각 단어 id 형태로 변환한다.

# %%
from sklearn.model_selection import train_test_split

vectorizer = CountVectorizer()
x_list = vectorizer.fit_transform(map(lambda i : i[1],x_text_list))

# %% [markdown]
# ### train test 분리하는 방법

# %%
print(x_text_list[2])
# Out:
# ('1546650266', '(AGCRIP 웨빙 포켓조끼 빅사이즈 조끼 MK321_324 아웃')

# %%
X_train, X_test , y_train, y_test = train_test_split(x_text_list, y_id_list, test_size=0.2, random_state=22)

# %%
# print(vectorizer.transform(list(map(lambda i : i[1],X_train))))

# %% [markdown]
# ### 몇개의 파라미터로 간단히 테스트 하는 방법

# %%
for c in [1,5,10]:
    clf = LinearSVC(C=c)
    X_train_text = map(lambda i : i[1],X_train)
    clf.fit(vectorizer.transform(X_train_text), y_train)
    print (c,clf.score(vectorizer.transform(map(lambda i : i[1],X_test)), y_test))
# Out:
# 1 0.61
# 5 0.602352941176
# 10 0.602352941176

# %% [markdown]
# ### 최적의 파라미터를 알아서 다 해보고, n-fold cross validation까지 해주는 방법 - GridSearchCV

# %%
# svc_param = np.logspace(-1,1,4)

# %%
# gsvc = GridSearchCV(LinearSVC(), param_grid= {'C': svc_param}, cv = 5, n_jobs = 4)

# %%
# gsvc.fit(vectorizer.transform(map(lambda i : i[1],x_text_list)), y_list)

# %%
# print(gsvc.best_score_, gsvc.best_params_)

# %% [markdown]
# #### 평가 데이터에 대해서 분류를 한 후에  평가 서버에 분류 결과 전송

# %%
# eval_x_text_list = []
# with open("soma8_test_data.dat",encoding=enc) as fin:
#     for line in fin.readlines():
#         info = json.loads(line.strip())
#         eval_x_text_list.append((info['pid'],info['name']))

# %%
# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
# print (pred_list.tolist())

# %%
# import requests
# name='test0'
# nickname='test0_text_svm'
# mode='test'
# param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
#          'name':name,'nickname':nickname,'mode':mode}
# d = requests.post('http://eval.buzzni.net:20001/eval',data=param)

# print (d.json())

# %% [markdown]
# #### eval 데이터에 대해서 분류를 한 후에  평가 서버에 분류 결과 전송
#  * 실제 여기서 나온 점수로 채점을 한다.

# %%
# eval_x_text_list = []
# with open("soma8_eval_data.dat",encoding=enc) as fin:
#     for line in fin.readlines():
#         info = json.loads(line.strip())
#         eval_x_text_list.append((info['pid'],info['name']))
# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))
# name='test0'
# nickname='test0_text_svm'
# mode='eval'
# param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
#          'name':name,'nickname':nickname,'mode':mode}
# d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
# print (d.json())

# %% [markdown]
# ### CNN 으로 추출한 이미지 데이터 사용하기
#  * keras mobilenet 으로 추출한 데이터, 이 데이터를 아래처럼 읽어서 사용 가능함
#  * 더 성능이 높은 모델로 이미지 피쳐를 추출하면 성능 향상 가능함

# %%
pid_img_feature_dict = {}
with open("refined_category_dataset.img_feature.dat") as fin:
    for idx,line in enumerate(fin):
        if idx%100 == 0:
            print(idx)
        pid, img_feature_str = line.strip().split(" ")
        img_feature = (np.asarray(list(map(lambda i : float(i),img_feature_str.split(",")))))
        pid_img_feature_dict[pid] = img_feature
#         print (line)
#         break
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400

# %%
from scipy import sparse

# %%
img_feature_list = []
for pid, name in X_train:
#     print(pid, name)
    if pid in pid_img_feature_dict:
        img_feature_list.append(pid_img_feature_dict[pid])
#         print (len(pid_img_feature_dict[pid]),type(pid_img_feature_dict[pid]))
#         break
    else:
        img_feature_list.append(np.zeros(1000))
#     break

# %%
img_feature_test_list = []
for pid, name in X_test:
    if pid in pid_img_feature_dict:
        img_feature_test_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_test_list.append(np.zeros(1000))

# %%
print(len(img_feature_list))
# Out:
# 6800

# %%
X_train_noun = extract(X_train)

# %%
X_test_noun = extract(X_test)

# %%
len(X_train_noun)
# Out:
# 6800

# %%
X_train
# Out:
# [('1231622364', '롤리팝 커플 핸드폰줄 2개세트/공예/교구/바느질/인형만들기/펠트diy'),
#  ('1538873662', '[핫트랙스] 체리 - [포장지훼손 특가] 스위트 미러 손거울'),
#  ('1494900501', '페르더마 타이트닝 샤워워시'),
#  ('675246799', '나무손거울/나무목걸이/나무메달/만들기재료/나무요요'),
#  ('1636081662', '예삐 테라피 고양이샴푸 360ml 1개(피부병예방) / 샴'),
#  ('1667581212', '레츠펫 캣타워 LP-1100 Black n White 애묘용품 캣용'),
#  ('1524017215', '[보리보리/마운틴 리서치]아동기모 웨이브 배색 팬츠/주니어'),
#  ('1315257728', '[It’S SKIN]베이비페이스 멜로우 스틱 아이섀도우 1.4g'),
#  ('1633213079', '바스켓3 커튼 4단행거 자카드 폭조절'),
#  ('1435290999',
#   '[알뜰구매]-키친아트 캠핑 쿨러백 5L와 아이스팩 시원한 캔 11개 수납 보온 보냉 접을수 있어 수납용이 어'),
#  ('1586265122', '체크 슬리퍼(남성용)'),
#  ('1500054056', '액자용 장식볼트 은색 다보 모음 DIY철물 / 볼트 다보 장식볼트 철물 DIY'),
#  ('1627953040', '클릭 02-10 크롬 도어캐치 익스테리어 몰딩'),
#  ('1561041482', '버터플라이 FTI 스포츠 타월'),
#  ('1572310445', '애니프렌즈 U자 대형 바디필로우'),
#  ('1218313863',
#   '[AKMUSIC]KAWAI 가와이 디지털피아노 CN-34 / CN34 [정품 블랙/로즈우드/화이트]전화문의시 최저가 안내!!!'),
#  ('1185365479', '꽈배기 니트 목도리 / 꽈배기목도리'),
#  ('1597062637', '롯데)레쓰비캔(175ml-30개입)-M806473 생활용품 사무'),
#  ('1694140186', '[BC카드10%][상해] 디즈니랜드 주말권 E바우처 (성인/아동/) 1일'),
#  ('73002411', '한국도자기 캐롤라인 2인조커피잔'),
#  ('1663304027', '(RA) (TG삼보) TG-UM150 64G 화이트 /슬라이드타입'),
#  ('1185359683',
#   '에어패럿2 지원 공식판매점/미라캐스트 SK 스마트 미러링 2.0 CAST 2200R 듀얼밴드 MIMO FULL HD IEEE 802.11'),
#  ('1463750981',
#   'USA umbrella-union jack umbrella-3단자동우산-성조기 우산-유니언잭 우산-미국국기 우산-영국국기-양산'),
#  ('1520491348', '(STRPhoenix_38_(피닉스38) 아웃도어 백팩 캠핑가방 스포츠가방 스포츠잡화'),
#  ('1455968832', '(밀알) (MachLink) CAT.5e UTP 다이렉트 랜케이블 50m /케이블류'),
#  ('1369288520',
#   'ONGUARD 5819 OG 케이블 콤보 락/강철 와이어 120cm 4자리 번호 변경 자전거 자물쇠 열쇠 번호키 잠금장치'),
#  ('1537116373', '무료배송 예스뷰티 휴대용 미니매직기 YB MINI MAGIC'),
#  ('1539655112', '순 실버 안구세정제_120ml 강아지용품 애견용품 반려'),
#  ('1481622823', '[압소바] 마리겉싸개 AQA-30302 (핑크,블루)'),
#  ('1611276419', '[바비루사] 하이스트바란스'),
#  ('770415665', '건습식청소기 T-401 (1350W) 보흥클레온청소기 산업용,업소용청소기 베스트툴'),
#  ('1407936917', '[Britz] 브리츠 컴퓨터 스피커 BR-ORION /2채널 우퍼형 스피커/PC용/USB용/노트북 사용가능'),
#  ('1459999524', '미니 팔레트 물감 붓 세트 15개 묶음 그림 미술 수채화 유아 어린이 아동 준비물 학용품'),
#  ('1613577666', '3M보안경/자전거고글/보안경/보호안경/고글/모음/2750'),
#  ('1451242037', '호주1위/왁스어웨이 웜왁스 350g/왁싱/얼굴 바디 브라질리언 비키니 제모/스트립 제모제 겨드랑이 제모기'),
#  ('1498517876', '카미의료용충전식석션기/ 뉴ASKIR230/의료용흡입기'),
#  ('1621101852', '여성플랫워커 [브라운]3912 3벨트 4.0 cm 여성워커'),
#  ('1596549041', '삼성 AA-PL2NC9B R710 XE2V 7350 R710-AA01DE/AS03'),
#  ('1291244275', '도장 명판주문(50x40㎜)만년자동 S-837 shiny'),
#  ('1207047420', '비타폴 이코노믹 일반 잉꼬 새모이 1.2kg/새모이/애완새'),
#  ('1622835253', 'TV정품 굿타임한방 족욕기/버블족탕기 각탕기 족욕통'),
#  ('1085572247', 'SONY 정품 MDR-E9 다이나믹 오픈형 이어폰'),
#  ('1352250838', '테이핑테이프/스포츠테이핑/스포츠테이프/테이핑요법'),
#  ('1581198392', '[디즈니랜드 입장권포함] 홍콩자유 2박3일[리턴변경 가능]'),
#  ('1608902990', 'F1 수려한 효비담 정율 - 로션 130ml/화장품'),
#  ('1291717336', '퍼프라스트야광목줄25/45(블랙)/ 목줄 강아지목줄 애견목줄 개목줄 애완견목줄 스텐목줄 훈련용목줄 강이지'),
#  ('1630534530', 'E1 (BOX) Cj 비트(리필) (2.7kgX4개)/세탁세제/d'),
#  ('1501267726', '프럼스마일 개별형 아답터 호주 뉴질랜드 WP 16'),
#  ('1617546597', '(흑)01972 9.0 cm 여성가보시힐/펌프스/하이힐/부티슈'),
#  ('1505243165', '[HP]1820-8G-PoE+ (J9982A) 스위치허브 당일발송'),
#  ('1611404288', '[하프클럽/uhlsport]HBT 멜란지 익스페디션 라쿤자켓 901머스타드'),
#  ('1414115778', '[프린스라이언하트] 젖병건조대'),
#  ('1128791516', '탑퍼태비힐링캣치킨스프50gX10개/고양이파우치/고양이스프/고양이캔/고양이간식/고양이용품/탑퍼캣츠파우치'),
#  ('1590861310', '이지조인트수전티_JTS2515_25x1_2 _(1EA) 주방수전교'),
#  ('1605511365', '명절 휴대용 제기세트 14P 명절휴대용제기 편리한제기'),
#  ('1570463076', '굿프렌드 참치+새우 캔 24개 1박스 고양이간식 애묘통'),
#  ('1187406604',
#   '익소몰[1300952-센툴]드라이버 빗트/6.3x110mm(＋)(－)/(BOX(10EA))/드라이버/드라이버비트/원형드라이버'),
#  ('1591105088', '(조익) 염모제 핑크(FP) 강아지용품 애견염색약 애견'),
#  ('1476416273', 'Coms 블루투스 헤드셋 화이트 무선 핸즈프리 / 블루투스헤드폰 블루투스헤드셋 무선헤드폰 무선헤드셋 무선'),
#  ('1256672757', 'TSS22A세트/어항세트/세트어항/유리어항/구피/열대어/물고기/어항'),
#  ('1074663868', '캘빈스 톰즈 컨스트레인드 큐브 270'),
#  ('1391199663', '번개맨벨트/번개맨/벨트'),
#  ('1060946297', '[56번가] 제브라 에어피트 라이트C 샤프 MAZ71'),
#  ('1334473563', '(무료배송)양키캔들 악세사리 윅디퍼 심지가위 라이터'),
#  ('1670132825', '미니멈룩_프리미엄 이카루스 35mm 샤기카페트 - 100x1'),
#  ('1258054785',
#   '뷔르트 펜타슬론 엔진오일 SAE 5W30 / 뷔르트 펜타슬론 SAE 5W40 엔진오일/1리터/연비향상/고출력 선택1'),
#  ('1328296522', 'ACER V3-571G 전용 고광택 저반사 액정보호필름'),
#  ('1578760285', '공간활용 깔끔 디자인 1단 식기건조대 씽크건조대 건'),
#  ('1559784416', '컬러립 쿠션잉크 틴트립스틱 립쿠션틴트 +아이샘플3장'),
#  ('761373676', '[성진마켓] 남양유업 맛있는두유 GT 고칼슘 검은콩깨 190ml 24개'),
#  ('1346975695', 'IEEE1394B 9P Bilingual to 4P 케이블 5M컴퓨터주변기기/IEE1394 케이블'),
#  ('1661204739', '라이프스토리[아쿠아리스트]수이사쿠 터틀 아일랜드 M /부상성 고정식 거북이쉼터'),
#  ('1289851795', '참넓적사슴벌레 암컷 30mm미만'),
#  ('1589576981', '프리미엄 아로마 양면 냉.온 찜질팩(사각형)'),
#  ('1633503540', '인테리어필름 포인트시트지 리버스체크 블랙펄 WBIM96'),
#  ('1344450503', '[올템] [SP489] 초슬림 블루투스 키보드[최대10M/무선/스마트폰/태블릿/노트북]/coms'),
#  ('1084330113',
#   '(종로)미국산/HIV바이러스 결과모형/AIDS 결과모형 79647/HIV와 AIDS의 결과를 3D모형과 함께 설명'),
#  ('1602380751', '(세계)완력기 1P_7218'),
#  ('1540019406', '한일파테크 드라이기/전문가용/업소용 PD-N2355WS'),
#  ('1252791152',
#   '(is) 브리츠 BR-1800T3/2채널스피커 앰프일체형/무선리모컨/원목 PC스피커/RMS출력 70W/매장/거실/TV스피커/PC스피커/BR-1800T3//스피커/컴퓨터스피커/브리츠'),
#  ('1669304609', '아디다스 베이직12 우븐 트레이닝수트(45625)'),
#  ('1396416633', '에이서 152 20V 6A 120W 충전기 아답터 아답타'),
#  ('850392688', '[치즈파티]미니 고다 스틱 20g*6'),
#  ('1620900474', '에스닉 쉬폰 롱 원피스/프릴/셔링/롱원피스'),
#  ('1014043814', '◀MD등록정품▶등산/런닝/모자/선크림/항균/에스뷰/김서림방지/코팅처리/페이스 선글라스 썬스크린 고급형/'),
#  ('1517032448', '[한시진플라워]철골소심[OW-4020] [축하화분/화분선물/집들이화분/승진선물/영전선물/인테리어화분]'),
#  ('1635895940', '다운2구소켓박스(5A) 5A소캣박스 시거잭연결박스 2구'),
#  ('945387328', '[3스프라우츠] 장난감정리함 스토리지빈 - 다람쥐'),
#  ('1567108004', 'E1 롤리스(테이프젤리) (21g x 50)/젤리/e'),
#  ('1603369687', '유닉스 전기/충전 겸용 유무선 이발기 UNT-A8990'),
#  ('1365682783', '[Womens Training] GS 쇼츠[AB5874]'),
#  ('906687883', '종근당 헛개나무즙 60포 헛개즙 헛개나무열매 헛개수 헛개열매즙 흑마늘즙 명절선물 부모님선물 홍삼액'),
#  ('1605082144', '쿠쿠토이즈 쿠쿠2인용그네/아기그네 아동그네 유아동'),
#  ('1595796701', '[갤럭시]GX 그레이 리넨실크 블레이져 재킷 (GA6811X543)'),
#  ('1665910329', '점보 장구방울'),
#  ('1636782990', '삼원)메탈OA용지(MC35.골드펄 A4 120g 10매) 삼원OA용'),
#  ('1486448205',
#   '[중국/항주(항저우) 호텔예약] 후아 지아 산 리조트 (Hua Jia Shan Resort(杭州花家山庄))호텔검색,호텔가격'),
#  ('1634626711', '영운악기 Sabian HH Vanguard 18인치 Crash 118VC'),
#  ('1481605286', '신상품/국내생산/백화점용/반팔티셔츠/골프웨어/카라넥셔츠'),
#  ('1024363189',
#   '[SONY][누리테크]SVP13213CKB(블랙)재고보유 단품구매가능 코어i5 1.06kg SSD 터치스크린 4GB 128GB 13.3형'),
#  ('894389795',
#   '[[강추위~걱정NO~!!]]한빛~튜브형~원적외선히터-6종/35~100사이즈-겨울계절가전/온풍기/보일러/전기히터/스토브/전기난로'),
#  ('1451543210', '[핫트랙스] 핑크/250mm - 펜던트코디 리본코디 가보시 펌프스힐'),
#  ('1170692241',
#   'LP 팔꿈치 보호대 #701 - 테니스 팔꿈치 서포트/보호대/압박/고정/관절보호/스포츠/의료용/팔꿈치고정/엘보'),
#  ('1614816275', '데일리 심플 스판 나시 원피스 택1 빅사이즈 나시원피'),
#  ('1384112415', 'iPad mini3 LTE[셀룰러] 64GB[공기계] 스페이스그레이'),
#  ('1330716633', '세련된 4mm 컷팅체인 실버목걸이 (41572-45c) 공용체인 선물용인기 골드조아'),
#  ('1499188090', '블랙박스상시전원연결케이블/폰터스 SB300/휴즈장착 /국산제품/품질우수'),
#  ('1431660554',
#   'BK2 금홍팬시 겨울왕국 핸드백 색칠놀이 1개 랜덤발송[324108] A102 색칠북/색칠공부_색칠공부 색칠북 스티'),
#  ('1008981735', '다미끼 포키스푼(14g,24g)'),
#  ('1548197419', '아디다스 피파 탑 레플리크 미니 스킬볼(AC5400) 1호'),
#  ('1596170305', '제임스딘 810 소프트발열소재 기모 편안한착용감 레이'),
#  ('1642984582', '카메라 모노포드, 최대 70cm(셀프촬영기기,타이머 기'),
#  ('1645619761', '조끼베스트조끼 고급조끼 베스트조끼 등산쪼끼 단체조'),
#  ('1467455810', '성인 벨리복세트 BDSET8501 밸리댄스복 벨리댄스복 밸리복 벨리복 벨리복 밸리댄스복 아동밸리복 벨리댄스'),
#  ('1481660712', '[나이키]LS 트로피 2 유소년 저지(100) /나이키 축구유니폼'),
#  ('1489492442', '칼론 잉글리쉬 불독 캐릭터 USB메모리 64G/선물용'),
#  ('1607350505', '제닉스 X-Loli 충전 USB 보조 배터리 - 오렌지a2'),
#  ('1687258128', '사무용품 클립보드 클립보드 크리스탈클립보드 A4(청'),
#  ('1637357531', '(홈아트)악어구구헤라 대 5023 신발주걱 휴대용구두헤'),
#  ('1539221106', '[KIPON] 멀티 스넵온 신형렌즈캡 67mm (고급형/분실방지기능)'),
#  ('1369317873', '샤워 및 목욕 겸용 접이식 이동변기/목욕의자, 야외활동 캠핑시 사용가능한 좌변기/이동변기 DH-601'),
#  ('1465597264', 'DK2 속옷정리함 12칸 색상랜덤발송[D460106] 리빙박스/부직포_생활 잡화 옷수납 리빙박스 부직포'),
#  ('1510724652', '영업용/산업용  건.습식 청소기  범퍼형 KS-500 보흥'),
#  ('1650615702', '바보디자인[아쿠아리스트]실리콘 인조장식 와이드 말미잘 /형광장식품 수족관'),
#  ('1630068048', '프랑스앰버라인/비트로블루밍/내열유리냄비-1.5L/편수'),
#  ('1592200957', 'Dog 구강세정제 면봉 36p 애완위생용품 강아지위생용'),
#  ('1626018849', 'TYAN KHT48 서버 E5-1650V3 CCTV 정품 빠른배송'),
#  ('1401521518', '(DW)[미샤] 니어스킨 셀프 컨트롤 필링 마사지 빠른배송빠른배송'),
#  ('1189325975', '각도조절 보조미러 2개 1세트 사이드미러 백미러 미러 차량용품'),
#  ('1649266080', '국가별 아답타/스위스 전용 아답타 with with USB'),
#  ('1713877688', '부안 리버 (전북 모텔, 부안군 모텔, 전북 모텔추천, 부안군 모텔추천)'),
#  ('1459437586', '큰솔교육 2.5cm형 5색 칼라쌓기나무 원목놀이 도미노 원목장난감 어린이장난감 칼라원목쌓기'),
#  ('1668304275', '잔가지 파쇄기/GS-360/모터 5마력/옥수수/사료/볏짚'),
#  ('1229940915', '아리따움 슈가볼 벨벳 블러셔 8g'),
#  ('1348813888', '다리관리 OX벨트 다리벨트 OX다리벨트 무릎쿠션 포함'),
#  ('118613754', '튼튼한접이식 빨래건조대2단/유아용/천정자동빨래수건이불건조대/트롬세탁기용품옥시크린하이슈퍼타이'),
#  ('1427433465', '질드진 18 ZHT Crash Ride'),
#  ('1085945758', 'SKC CD-R 1P/공시디/공씨디/공미디어/컴퓨터주변기기/SKC시디/DVD-R/RW'),
#  ('1482852672', '[리피트리(Leafytree)]아카이 편백나무원목 2100 거실장 세트'),
#  ('1522318143', '(HD한일전기 업소용 청소기_HC-1900W 업소가전 산업가전 업소청소 산업용청소기 업소용청소기'),
#  ('1632933845', '라텍스 애견신발 블루 M/배송비 선불만 가능'),
#  ('1706755515', '넘버뱅크 비밀번호금고 건전지 AA 3개 포함'),
#  ('1631739953', '아동화 iz이선지퍼 슬립온 단화(sn)/ 바나나팜스'),
#  ('1603949716', '리페어포스 키토 트리트먼트 CMC 200ml'),
#  ('1508194430', '폐수저항피팅 FR-600 1/41/4 600ml'),
#  ('1648025386', '홈쇼핑매진상품 메르꼴레디 극세사 입체토퍼 Q 1 + 1'),
#  ('1302175273', '[한국소재과학]스텐션 시험관대'),
#  ('1138097693',
#   '남성 /페로몬 향수/남자향수/특가/프랑스 원료 사용/남자 페로몬 향수/50ML/가을 겨울 사용하기 좋은 향수'),
#  ('1557251163', '[더리드 (THE LEAD)]벤더 투서랍 장롱9R[갤러리아]'),
#  ('1568705453', '입구 메뉴판거치대 / LPM 원목스탠드 ZLM-DM2L 대형/'),
#  ('1631250033', 'KFT 2200561 화이바 요비선 0305FAH 15m (1EA)'),
#  ('1534499221', '3배율 돋보기-5개/어르신독서용돗보기돋보기확대경'),
#  ('1279040952', '미스터펫 이중커버 도넛방석 코튼캔디 강아지집 강아지용품 고양이집'),
#  ('1490300659',
#   '[무료배송] 파리 베르사유 궁전 입장권 /베르사이유 궁전 입장권 - 궁전 관람!! 줄서는 번거로움 없이 입장!!'),
#  ('1469565899', '[BOOSTER] 부스터 샤카 그레이 보드숏'),
#  ('1622565334', '휴대용 삼각다리 체어 네이비 캠핑의자 등산의자 낚시'),
#  ('1566143374', 'E1 옥시 냄새먹는하마 냉장고 참숯 750L 300g/h'),
#  ('1114017594', '시원한 지압매트 470 둥근자갈형'),
#  ('397876189', '[이파람]PW-F24CBS/냉방전용/79.2㎡실외기없는에어컨/수냉식에어컨/이파람에어컨'),
#  ('1423379264', '나팔꽃？ ？-넝쿨조화 ？ 셉똑？ 인테리어조화 장식조화 조화꽃 벽장식조화 조경장식 나팔꽃 담쟁이'),
#  ('1640545105', 'if 하오베에어투웨이케익 13호 누드베이지 1개/b'),
#  ('1603578537', '패브릭버튼3인스칸디나비아소파 /북유럽인테리어'),
#  ('1565410027', '차량햇빛가리개 모빌형 6종 택1 햇빛가리개 차량커튼'),
#  ('1224394464', '(맛나)살코기참치(안심따개)100g/사조'),
#  ('1536077249', '버블 펫 스텝 (삼각_그레이) 애견용품 애견이동식계단'),
#  ('1490887309', '목각 폰(mock-up), 모형 갤S4/White'),
#  ('1656305393', '[노르웨이 연어] 노르웨이 항공직송 FRESH 연어세트 6호'),
#  ('1491652878',
#   '[NewLife] LG테크꿉꿉한냄새걱정끝리필 5kg(K4720) 세탁비누/세제/섬유유연제_세제/액체세제/세탁세제/슈퍼'),
#  ('1580725807', 'JT -50H /스킨스쿠버/ 부력조절기'),
#  ('1154354216', 'BMW X6 M (KY225910GY) X시리즈 모형자동차'),
#  ('150642776',
#   '[중고]SKT공기계 LG-SH860 와인폰3 효도폰 3G 폴더폰 큰화면/큰버튼 FM라디오 외장메모리 無약정 공기계 중고폰 선불폰가능'),
#  ('101155814', '엠세라드 에너지 투페이스150ml/수분공급/헤어에센스/미스트/매끄러운 머릿결헤어스타일링/워터타입'),
#  ('527958349',
#   '3M]LP-6000 Plus  레이저포인터/프리젠터/레이저포인터/포인터/프로젝터/빔프로젝터/회의용/강당용/강의용'),
#  ('1509408149', '[베베마켓] 쇼니 (유기농) 고양이헤어볼 샴푸 500ml (백합향)'),
#  ('1353915608', '성광 에어파스 쿨 200ml x10개 //스프레이파스'),
#  ('1664615325', '분홍둥근영아책상(높이290) 유·아동 책상'),
#  ('1439327976', '[무료배송] 모던물받이화분정리대1단 화분받침대 화분정리대 화분진열대 화분받침 화분받이'),
#  ('821469247', '아이수 국내산 고창 복분자 진액 500ml x 4병/복분자원액/복분자즙/복분자진액/복분자엑기스/복분자쥬스'),
#  ('1670899197', '2017년올뉴모닝 측후면열차단썬팅필름 5%/헤라기증'),
#  ('1540368030', '[쉬즈홈] 모던라이프 DTP 선풍기커버'),
#  ('1257800179', '[삼현제약 청솔 과산화수소수 4L] 환부의청소/상처면의소독/질세척/구강세척/탈취제/무색투명액/의약외품'),
#  ('1622548190', '랑콤미라클/프래그런스오일100ml/캔들/디퓨저'),
#  ('1048085121', '[키즈돔] 코끼리 차렵이불 매트커버세트(싱글/슈퍼싱글) / 아동주니어침구'),
#  ('904024246',
#   '10m 15m 전원케이블 3구전원 3구전원케이블 3구클로버 3구크로버 컴퓨터 모니터 TV 노트북 프로젝터 LG 미니빔 빔프로젝터 빔프로젝트 클로버 크로버 전원 케이블 3구 클로버전'),
#  ('1655998603', '[스케쳐스] 스케쳐스 포미 메모리폼 쿠션 아동화 SS0BA15X011'),
#  ('1195250547', 'C.S LG전자  무선 Nano 2.4Ghz CM-1400 (블랙)'),
#  ('1613714098', '[O.C. Lab] Black& Red 오버클럭PC 2 정품 빠른배송'),
#  ('1662268869', '콩마트 뚜레반 메밀부침가루500gX3개'),
#  ('1661036554', 'HP 250 G5-Y5X25PA보안필름/거치형'),
#  ('1320488214', '한샘 프리미엄 윈도우 99㎡_30type'),
#  ('1550091934', '셀로트 DMB샤크 CV7000 (쉐보레 자동차용)'),
#  ('1665440153', '3M 마스크 7502 방독세트 7502+6003'),
#  ('1413842618', '[레어풋SH25] 아디다스 슈퍼스타 트랙탑/M30909/아디다스트랙탑/아디다스져지/아디다스트랙자켓/매장정품'),
#  ('1400485618',
#   'HP DL360p G8 (E5-2609 2.4G 4C / 12GB / 300GB X 4) 옵션문의 : 070-8163-0759 HP Server'),
#  ('1421020348', '(GELID) SLIM SILENCE AM1 /쿨러/튜닝'),
#  ('1539802263', '(스킨푸드)라이스 컨실러 팁 23호 내추럴 베이지 매끄'),
#  ('1553100964', '가시엉겅퀴 패드 6매 25봉입/농축액 발열패드'),
#  ('1665898884', '투명 칸막이 모이통 [휜치,소형앵무용]'),
#  ('9839035', '꼬레촌서류 감자 햇감자 특(1번)큰size 10kg/box'),
#  ('41305492', '[동원] 완도 어린미역 90g (20봉) 한박스/ 무료배송/김 다시마 미역 동원미역 완도미역 동원어린미역'),
#  ('1108690481', '(추천)[강남미녀 천일염세트 병5종]강남미녀 천연소금세트/건강천연소금/바베큐천일염/바베큐소금/건강소금'),
#  ('1448035699', '[스카몰]할릴릿 돌잔치악기선물세트[MS9008] 상품다양 상품다양'),
#  ('1607684803', '[스쿨뮤직]RICO La Voz 소프라노 색소폰 리드 Medium Soft (색소폰, 섹소폰)'),
#  ('788781937', '봄들산야초 쑥초 720ml 3병'),
#  ('1635695285', '옐로우로즈 허브화분 -조화 장식 화분'),
#  ('1410630059', '돌체구스토호환캡슐 [개당458원] 네스카페 호환 캡슐'),
#  ('1432975509', 'SOL헬멧 / SO-1 SOLID Black / 오토바이헬멧'),
#  ('1613342982', '목욕 겸용 접이식 이동변기 목욕의자 DH-601 샤워겸용'),
#  ('1581302014', 'USB공기청정기 황사 컴퓨터 노트북 공부방 탈취 공기'),
#  ('1421908380', '(피부관리샵 공급용) 루이셀 쿨마사지크림750g'),
#  ('1209811047', '제이키드 수경 RACE JXOL004_PK'),
#  ('1084673212', '나이키 3PPK 드라이핏 라이트웨이트 크루 (SX4831001) (SX4831-001)'),
#  ('1678302793', '버우드 이스트 모텔(BURWOOD EAST MOTEL)'),
#  ('1238571963', '[smalll size] Book & Tea  도자기 티 포트'),
#  ('1560580552', '데이타임 다용도 잡주머니 XXL(48x65) 캠핑용품 멀티'),
#  ('1358324292', '[HOBBY_반다이10%적립]요괴워치 12 타올라이온 (KR) [무료배송]'),
#  ('1546510485', '고급 명함케이스(B-003) M420457 명함보관함 메모꽂이'),
#  ('1462533663', 'JU 삼성전자 정품 박스 노트3배터리/EB-B800BKBEC/3200mAh/내장형배터리'),
#  ('121605622',
#   '캐논 RC-5 / 니콘 ML-L3 호환 무선리모콘 선택형, EOS550D/60D/500D/450D/400D/350D/300D RC5완벽호환, 니콘 D90/D80/D70S/D70/D'),
#  ('1560857613', '바스존 겨울왕국 스노우엘사 EVA 샌들 (사이즈선택) -'),
#  ('1650808942', '[ATB]SHIMANO ULTEGRA RD-6800 11단뒷드레일러/변속기'),
#  ('1520568852', '코일 세차호스 15M/물호스/릴/물청소/호수'),
#  ('1623554182', '엔보우 카드형 티지원 오티지 슬라이드 2.0 USB메모리'),
#  ('1183828599', '[영공방][디오라마] 시크릿가든/김주원/모형/조립/미'),
#  ('1557108984', '제스파/옥 힐링 지압슬리퍼/발지압/신발/발바닥/건강/'),
#  ('1529477931', '월드프로정품 차량용 소화기119 소화기 올뉴스포티지'),
#  ('1528944811', '엠펫 고양이2구터널(줄무늬호피 AA-04) 고양이쉼터 고'),
#  ('70528549', '[펜플] 도너랜드 칼라점토/칼라찰흙[8색]'),
#  ('1426078506', '던롭 EDITION 머니클립'),
#  ('1232892981', '[A]가가 고급회전다트 (소)/다트게임/회전다트/다트/게임/장난감'),
#  ('1620867062', '스파이더맨 거미줄 방한부츠 /유아 아동부츠'),
#  ('1556992743', '헤어드라이기/원적외선/옥풍/드라이/두피/모발건강/옥'),
#  ('1545045191', '원목 흔들말 (대나무 목마) 아기흔들목마/유아용흔들'),
#  ('1694049021', '인테리어 데코 소품 앤틱 미니어쳐 메모홀더 메모 꽂'),
#  ('1564461690', '네트워크분배기 NETmate 고해상도 2:1 모니터 자동 분'),
#  ('1649368241', '더허브스토리 버블바스 1000ml 1개 택1 버블바스 거'),
#  ('1579374925', '정품 삼성 청소기 물걸레 브러쉬/사용모델:VC-MB755Z'),
#  ('1326388222', '(라움스튜디오)스크류 블랙봉 (일반-2.5cm) / 블랙 커튼봉/ 25mm / 일반봉 / 커튼봉 / 블랙'),
#  ('1390981784', '비화옥-구형선인장/킴노칼리움/턱선인장/선인장'),
#  ('1671531260', '(회)왕끈 하이탑 털운동화'),
#  ('1248651157', '접이식원목의자(701외)/야외용/까페의자/데크의자/접의자/식탁의자'),
#  ('1565654501', '케어존 닥터솔루션 안티 링클 아이 크림 (25ml)'),
#  ('1053591920', '[앙상블커튼] HS-듀오 매직 콤비 롤블라인드 95X240cm'),
#  ('1514123202', '애견가방 모음 강아지가방 고양이 애완 캐리어 강아지용품 이동장 강아지집'),
#  ('1450661765', '본덱스오일스테인 750ml 반광 친환경천연방부방충도료'),
#  ('1631611249', '[코첸]렌느 통5중 스텐냄비 전골24cm 냄비세트 냄비'),
#  ('1589348972', '원목바둑판(HJAS21A)문구 교재류 준비물 놀이교재 바'),
#  ('1009506095', '슬라이드각도절단기 LS0714FL MAKITA-마끼다마이터쏘 컴파운드쏘'),
#  ('1710927142', '산키스 탁상용제도기 자석 SK-PDM-609 -33060 제도기'),
#  ('1121532539', '385[WOMEN belt]최신상 팜므컬렉션 벨트 3종/정장벨트/케쥬얼벨트/코팅가죽'),
#  ('1633203790', '(LG전자) Super-Multi GH24NSB0 블랙 정품벌크 /ODD'),
#  ('1537077064', '아로마에센셜 풋 밤 56g 강아지용품 애견발바닥관리'),
#  ('1440568975',
#   'IPTIME 아이피타임 A6004ns 4포트 기가비트 유무선공유기/Wi-Fi/무선공유기/듀얼밴드/기가/USB포트'),
#  ('1628301457', '바이하츠 로봇 스테플러 R-800 R800 자동 33호침'),
#  ('1636980151', 'Tf 바세린 헬씨 핸드앤 스트롱거 네일 로션 450ml/b'),
#  ('1041691443',
#   'AZ [제록스] DocuPrint P255dw/흑백레이저프린터/토너포함/128MB/30ppm/자동양면인쇄/무선네트워크지원'),
#  ('1667617552', '넥타이 셔츠 넥타이핀 생일선물 타이핀 48846 넥타이'),
#  ('1438292226',
#   '(추천)키친아트 느와르(Noir B ack) 경질 압력솥 3.5 (5인용)주방용품 냄비 부엌 냄비추천/ 키친아트냄비'),
#  ('1201205790', '대한민국 최저가 valve Trombone 밸브트럼본 초특가TB-508 정품트럼펫 운지법동일'),
#  ('1457146711',
#   'ZOJE 9503-B01 조제 고속 1본침 수동 본봉 다이랙트 무소음 모터 내장형 미싱샵이벤트+전국 최하가 이벤트'),
#  ('1365173435', '1314 버즈런 마제스타 보아 부츠 블랙'),
#  ('1544132016', '워렌런던 하이드레이팅버터 애견 컨디셔너 린스 240'),
#  ('1059296018',
#   'ARAS 아라스 정품 갤럭시노트3용 보이니2 배터리 뷰 커버 케이스 갤럭시S5/S뷰커버/전면커버/배터리커버/배터리뷰케이스/스마트폰/플립커버/플립/케이스'),
#  ('1687036091', '스마트키 차량 번호 넘버링 키홀더 열쇠고리 악세사리'),
#  ('1517284206', '(디엠지샵) 위에마이 신형 반팔 컴뱃 셔츠 (Snake Camo Tan)'),
#  ('1521737222', '로켓배송/ [크림스랩] 웨이스트 백 VER.4 스트라이프카키 + 호루라기파랑/남자여자힙색/힙색브랜드추천/웨'),
#  ('1483563758', '파시 풍선 티나 컨실러 비비크림'),
#  ('1373950420', '특가-3M 항균 천연펄프 다목적 수세미'),
#  ('1606608529', '(나이키 텍스처드 폼롤러 (050)) 요가밀대 스트레칭'),
#  ('1518565859', '미닛메이드(병)오렌지180mlx12x3개 코카콜라'),
#  ('1618026166', '캣 워터에이디티브(구취제거) (약453ml) 강아지용품'),
#  ('1485718312',
#   '[스카몰]10묶음)펜텔 아인 샤프심 C257-HB 0.7mm 40본입 아인샤프심 고급샤프심 필기용샤프심 다용도샤프심'),
#  ('1552591925', '고급손가락보호쿠션 문닫힘방지쿠션 가정용손가락보호'),
#  ('1411484864', '(T)ICECAP 775 Yellow /싸일런트 유체 /CPU 쿨러/쿨러/쿨링팬/FAN'),
#  ('1271870400', '브리츠정품 Britz BR-1000A2 2채널 멀티미디어 데스크 스피커/빠른배송'),
#  ('1376923322', '[제주/렌터카] 제주/렌터카/제주렌터카/24시간기준/예약권'),
#  ('1596987764', '(SWS 압박 니 삭스 여성반양말 반양말 반스타킹 발목'),
#  ('1332902110', '호루스벤누 RX-360DV 유압식 도브테일 비디오헤드'),
#  ('1383198337', '[누비유통]PVC 플라스틱 재질 LED 라이트 확대경 돋보기 확대경 라이트 플라스틱확대경 다용도확대경 휴대'),
#  ('1393074905', '[윈지커머스]DYT코너용쿠션커버 4입 안전용품 모서리안전보호대 모서리보호대 모서리쿠션 코너보호대 상품'),
#  ('1320545261', '빅블루 수중랜턴/수중전등 플라잉피쉬[1X5W]'),
#  ('1445641552', '(일신 금형 세정제 420ml x 10개) /금형세척/오염제거'),
#  ('1636405802', '노바15cm씨리얼볼-아쿠아'),
#  ('1626275869', 'Tf 다우니 아로마플로럴 3L 1개/섬유유연제/v'),
#  ('1450691344', '[마루모터]메이햄 토렌2 3260/블랙레드링/18인치10홀'),
#  ('1690943289',
#   '제주 서귀포잠수함+이상한나라앨리스 제주도 관광지 2곳 패키지 입장권 할인 /기프트제주/제주 승마체험/제주 승마/제주승마할인/제주 승마장 추천/제주도 승마체험 가격말타는곳 말타기'),
#  ('1583558921', '프리마 바로헤어 흑채 순간증모제 23g 탈모 여성흑채'),
#  ('1552065446', '1엠보싱화장솜210매_화장솜_면봉_이미용품_위생용품'),
#  ('1564119818', '(JJH 홍진 탁상용 선풍기_HJ-16 가정용선풍기 개인용'),
#  ('1099107545', '나루예 홍한set /최고급명품찌/부드러운 수직입구/숨넘어가는 찌올림'),
#  ('1462178446', '나르샤 핑크 어린이집 앞치마/선생님/교사 앞치마'),
#  ('1598057929', '데톨 손소독청결제 겔 오리지널 200ml PLM'),
#  ('1573859930', '(PLM백설 진한 참기름2호 선물세트 추석참기름세트 참'),
#  ('1095866798', '보령 홈라이프 매트에스 60매 x 3박스 //홈매트'),
#  ('1598206708', '바이오프리즈 블루4oz(2ozx2개)(유효일2017년3월)'),
#  ('1689145771',
#   '제주 헬로키티아일랜드+산방산탄산온천  제주도 관광지 2곳 패키지 입장권 할인 /기프트제주/제주 승마체험/제주 승마/제주승마할인/제주 승마장 추천/제주도 승마체험 가격말타는곳 말타기'),
#  ('1378737226', '시트마켓 cs082-잠자는 양_칠판시트지_칠판스티커'),
#  ('1516646729', 'WinTV HVR-1265'),
#  ('1215320280', '골드마요네즈300g/오뚜기'),
#  ('1357043338', '[NATURE REPUBLIC]수딩 앤 모이스처 알로에베라 폼 클렌저_150ml'),
#  ('1213318043', '심로 바이올린 활 SNB 432 / Shimro Violin Bow SNB'),
#  ('1608121217', '(볼트 깃털 셔틀콕(V100) 12개입) 배드민턴 셔틀콕'),
#  ('1423537573', '이스타 디지털 스텐 2중 무선포트 1.2L'),
#  ('1413108811', 'Stylish Dangle 귀걸이 Blue 스와로브스키 .925 Sterling Silver'),
#  ('1419077154', '[브레이크] 105 브레이크 5800(앞/뒤세트)/시마노 105 브레이크 앞,뒤 5800'),
#  ('1447792549', '[쿨룩] 슬림핏 퀼팅디자인 코튼 블렌드 셔츠 EVS109'),
#  ('1384369600', '[에뜨와]비타민욕조[핑크] (77F0 86001)'),
#  ('895891071', 'PM/그랜드우성 김치냉장고WSM-360K(1,2도어)-서울무료'),
#  ('37010335', '기저귀가방'),
#  ('1347497296', 'y1452 머핀 미니토트백 크로스백 동기상사 영앤비 아동과 같이'),
#  ('1394272301', '자바/POP12색/사각매직/전문가용/유성매직'),
#  ('1167239300', '매표)사각 회중인주'),
#  ('1168366420', '[제주허브렌트카 - 제주도렌트카 가격비교, 85% 최고할인] 올뉴쏘울 (휘발유/오토) 24시간'),
#  ('1675589378', '1600-2167 BMW 그란투리스모 35i xDrive 리스 장기렌트 전화상담무료 1600-2167'),
#  ('1444129473',
#   '알파 일회용밴드 표준형 24매 (73X18mm)/ 상척드레싱 드레싱밴드 반창고 드레싱 상처밴드 데일밴드 밴드'),
#  ('1560729989', '셰프라인 미니 전기오븐 컴팩트 그릴 베이킹 토스트'),
#  ('1508661749', '남성소변기 ABP105/간이변기/환자용소변기/국산'),
#  ('12889837', '콜크게시판 900×600 콜크보드 문교교재 게시판 보드판 메모보드 콜크판 코르크보드판'),
#  ('1601291089', '(리툰)스퀘어 파우치 M(등산 여행 파우치) 0357_00007'),
#  ('1406765722', '필웰쿠엔코수납장세트(서랍둘)+식탁'),
#  ('1614017142', '주니어 드럼세트/524351'),
#  ('910428553', 'ATEN UC-100KMA USB to PS/2 Converter UC-100KMA 27475'),
#  ('1290313351', '[보쉬]  AQT 37-13 PLUS 130bar 가정용 소형고압세척'),
#  ('1642821786', '조립식 아크릴 햄스터 은신처(중)빌라1-하늘SAG-081-3'),
#  ('1483024945', '[SONY]하이엔드 컴팩트 4K 핸디캠 FDR-AX30'),
#  ('1295889985', '[당일배송] Rio fish net 뜰채 5인치/열대어뜰채 수족관뜰채 어항뜰채 수조뜰채 미니뜰채 관상어'),
#  ('1501758070', '라벨라F 밀피유 1200 홈바 (착불)'),
#  ('1589279956', 'KTM 450 EXC 09 오토바이모형 바이크모형 오토바이 미'),
#  ('1209630109', 'FM21-알세도 TS2308R'),
#  ('1130581748', '2016 FW 남성 골프웨어 기능성 골프티셔츠/삼공오공'),
#  ('1556527950', '바로크홈 퍼페딕 접이식 매트리스/ 베이직 12cm 싱글'),
#  ('1503312197', '새한 리브겐 헤어 글레이즈 450ml/마일드한세팅력/자연스러운윤기/웨이브탄력/매끄러운머릿결'),
#  ('1373355960', '뉴아이패드 벨트케이스/아이패드악세사리/뉴아이패드용케이스/아이패드커버/newipad/뉴아이패드케이스'),
#  ('1388157736', '[2개무배+NO옵션] 인도산 강황분말1kg 강황환300g 강황600g 울금 울금환 울금가루 커큐민'),
#  ('1603797142', '펫퍼스 샴푸 모든개용 400ml 배송비 선불만 가능 애견'),
#  ('1408816019', '발코니매트 다크월넛 50cm/1cm/베란다매트/놀이방매트'),
#  ('1468480597', '[알뜰쇼핑]-오가닉 끈스타 나시티 배송비 선불만가능 애완용품 강아지간식 애견간식 애견영양간식 애견'),
#  ('1603296781', '[필그린] 자동히터 어항용 100W'),
#  ('1517284373', '펫시 크리닝 브러쉬(털자동분리),소 / 탈취제 애견향수 애견위생 털관리 애견목욕'),
#  ('1548612873', '인드로카라페 0.5L 물병 쥬스병 우유병 피처 주방용품'),
#  ('1562413411', '엔젤 멜로디언 AM-P37 (핑크) 영창악기 악기 멜로디혼'),
#  ('117325561', '스테들러 제도샤프 92525(A급) 0.3mm 0.5mm 0.7mm 0.9mm/샤프심'),
#  ('1524518601', '[1358k] cp204-산토리노의아침_유리문시트지'),
#  ('1520133183', '[스위스밀리터리] 대형 돌고래 튜브 / 캐릭터튜브 물놀이용품 수영장튜브 보트'),
#  ('1438667945',
#   '[hdp] 1_24 1985 Honda Today 자동차모형 자동차모형 인테리어소품 장난감 조립자동차 모형완구'),
#  ('1571335993', '바슈롬 리뉴 후레쉬 355ml 3병'),
#  ('1163603581', '이태리 크레씨서브 나노 HD 스쿠버 마스크/스쿠버마스크/다이빙 마스크/스쿠버 수경/다이빙 수경'),
#  ('1674106464', '펜텔 아인 샤프심 C277-B 0.7mm'),
#  ('1616033108', '[패션플러스][콜핑][남성]초경량 후드 다운자켓(KMJ6643M오렌지)'),
#  ('844262968', '(호주/케언즈)케언즈 비치 하우스 리조트/CAIRNS BEACH HOUSE/케언즈 시티 센'),
#  ('1482794469', '[상일리베가구]소나무 원목 테이블 1000'),
#  ('1437993683', '[가평,양평]_바하마, 물놀이, 수상레저, 수상스키, 웨이크보드, 바나나보트, 땅콩보트, 워터파크, 펜션'),
#  ('316294944', '껍질째먹는 자연애 세척사과세트(5kg 21과내외)'),
#  ('1640707148', '플라튜브 쉐드 브러쉬 색상임의'),
#  ('1518766404', '(애견덴탈껌 덴티스타) /강아지껌/양치기능/스틱껌/개'),
#  ('1243203336', '(정품) 파라핀왁스/오렌지향/파라핀베스/뉴젠/아이젠/리필왁스/국산'),
#  ('954852049', '[야마하공식총판] TSX-B72 다크레드 블루투스 오디오'),
#  ('1644465258', '바둑판(400*440*20mm)문구 교재류 준비물 놀이교재 바'),
#  ('1473512377', '[오가닉맘]트리엄남아똘이모[MAM7HA01]'),
#  ('1644347067', '[대구백화점 I관] [치크]와이드데님(CKTJ721Q1G)'),
#  ('1586639178', '선풍기 안전망 고급형(먼지필터형)'),
#  ('1564516319', 'if 코텍 참숯 키높이 안창 검정색 사이즈 FREE 5개/c'),
#  ('1374670494', '특가-코코맘 캡3단 다용도정리함 정리 기저귀정리함 다용도바구니 기저귀함'),
#  ('1604938783', '신나라 무선 듀얼팬 미니 선풍기 고급형 작은선풍기'),
#  ('1529588265', '[BC카드10%][괌]언더워터월드+씨그릴 레스토랑(성인/아동/) 1일'),
#  ('1523802673',
#   '[wss] 화이젼 Fizzion 애견용 얼룩 및 탈취 솔루션 애견 애완동물냄새 냄새제거 강아지탈취제 애견탈취제'),
#  ('1400807393', '(GM)[마몽드] 자스민 캐시미어 바디로션 250ml 빠른배송빠른배송'),
#  ('1285010991', '나이스텍 나이스워커4E 실버카 보행 보조차 4륜 보행'),
#  ('1630082180', '이화SMP V-MAX  ET-7350D 준클럽용헬스 중고 일렙티컬'),
#  ('1255629273',
#   '[중고]시크릿하우스구제/ 리바이스/여성/26/부츠컷청바지/빈티지워싱/부츠컷/청바지/진청색/67/86-90(26)'),
#  ('1472749160', '무배 미쟝센 펄샤이닝 모이스처 린스 780+780ml'),
#  ('1665907605', '다이아퀼팅 배색스티치 여성 패딩 보온 바지'),
#  ('1153536812',
#   '[ROCCAT] TYON 애즈윈 마우스 / 레이저 / 유선 / USB / 8200DPI / 12000FPS / 14버튼 / 상하 / 매크로 기능 / 꼬임방지 케이블 / LED 튜닝'),
#  ('1630532674', 'E1 (BOX) 엘지 테크.드럼용(액체)리필(2L+2L) x 3/h'),
#  ('1660674545', 'F (Lite-On)  DVD MULTI 내장형 iHAS124 /ODD'),
#  ('1497786142', '무료 슬레진저 810 로딕구 여성 운동화 240-245'),
#  ('1454431020', '프로유 챠콜 모델링 마스크 1kg (202) 스킨케어 감성충만'),
#  ('1639146790', 'NT 디자인커터 H-1P 사무용칼 문구용칼 컷터칼 문구칼'),
#  ('1529581460', '[BC카드10%][대만] 택시투어 1탄 - 예류,스펀,진과스,지우펀 E바우처 (성인/아동/) 1일'),
#  ('276056777',
#   '[저소음 쾌적한 고효율 난방실현!]대성하이원 리모콘 원적외선 튜브형 난방 전기히터(8~13형)[DSPE-50]'),
#  ('1316510629', '사각통발 원형통발 그물망 뜰망 투망 새우망 어망 문어통발 장어통발 와이어망 포획망 참게 꽃게 채집'),
#  ('1393708093', '멜버른,울룰루,시드니 9일 [울룰루 2박3일 캠핑]'),
#  ('1574696025', '시골선물장화무료배송 [KS-말표 여성장화 N] 주방장화'),
#  ('1349483308', '반려견LED안전목줄'),
#  ('1566277841', '추석미리준비하세요! 간장(진 S 샘표 1.8L) X 6'),
#  ('1582114078', '베이블레이드 B-28 부스터 넵튠 아머 제퍼 (20288) 배'),
#  ('1500134655', '[아레나][아동수영복] 여아동 원피스수영복+바지셋트[ASBGO62NVY'),
#  ('1626931371', '봉래 장구관 (42개입)/ 강화약쑥 쑥뜸'),
#  ('1447227826', '[GAB] 콘츠 배낭 등산 가방 캠핑 여행 산악 고급 대'),
#  ('1311281771', '구급가방 GM 홀스터 팩(아웃도어 구급키트) 비상약품'),
#  ('1518850839', '정장넥타이 남성선물 넥타이 패션넥타이 H23'),
#  ('1238907973', '아메리칸 스탠다드-해바라기 레인 샤워 세바2 KF-5820'),
#  ('1559808152', '밀가루 피자전용분 백설 10K 분말류'),
#  ('1482701266', '**아이코닉** 폴딩 캐리백 (접이식 빅사이즈 여행가방/캠핑백.소풍가방.기저귀가방)'),
#  ('1574048181', '레고 지우개 2P (블루,옐로우)(레드,라임)'),
#  ('1482403406', '3M 포스트잇 슈퍼스티키 노트 SSN-656/포스트잇/3m메모/메모지/플래그/포스트이트/메모/연습장/노트'),
#  ('824942072',
#   '[구매대행]피셔프라이스 디럭스 원숭이 바운서/피셔 바운서/부스터/락커/Fisher-Price Deluxe Monkey Bounc'),
#  ('1606948287', '스노우볼 양말 블루 (S-L) 양말 강아지양말 애완양말'),
#  ('1406515966',
#   'K73PGY [LG] 진공청소기 [슈퍼싸이킹3주니어/트윈싸이클론/헤파필터 H14급/먼지통 1.2L/청소]ens'),
#  ('1474876940', 'LG G5 무선 블루투스 이어폰'),
#  ('1642122767', '패핏 체크대형숄 겨울목도리 남성의류 패션의류 남성'),
#  ('1446255055', '(2단 생일케이크-녹음기능) /역할놀이/소꿉놀이/요리/'),
#  ('1474292601', 'B14837/23000 요술공주 미나/ 마론 바비 인형 마론인형 봉제인형 인형놀이 인형놀이세트'),
#  ('1447525841', '강아지핀/애견핀/악세사리/빗살핀/똑딱핀/애견머리핀/집게핀'),
#  ('1320347570', '화이트 수지점토 200g 불투명 문구용품 조소 만들기용품 조소보조용품 점토'),
#  ('1298868155',
#   '[헤라] 헤라 전기 헤어 클리퍼 - HR-280 [헤라] 헤라 전기 헤어 클리퍼 바리깡 [헤라] 헤라 전기 헤어 클리퍼 바리깡'),
#  ('1370738951', '한지마감재(가루풀.100ml)/한지공예/한지체험학습문구코리아'),
#  ('1557416163', '이동식앰프/이동식엠프/JEZ1298'),
#  ('1126375627', '[매니퀸] 레더(천연소가죽) 마우스패드'),
#  ('1374835918', '당일발송 서예아이 흡주연 벼루(원형) 15cm STN-7-3'),
#  ('1617015817', '앨리스고즈홈 아로마 피톤치드(올리브) 암막겹가공 400, 봉, 링'),
#  ('1414741186', '[IDPOSS]아이디포스 착시 키높이 2cm깔창 여성용 스트라이프블루/향균탈취살균/발냄새/발건강/키높이깔창'),
#  ('1097540121', '순금 골드바 카드 0.5g 99.99% [ 복돼지 ]/ 골드모아'),
#  ('1337998534', '[중고]P-912 노스페이스 여성 등산 팬츠'),
#  ('1643148958', '미니특공대 키즈방한대 30개/어린이마스크/방한마스크'),
#  ('1432741326', '솔티 파이터 맥스 좌핸들 아부가르시아 베이트릴 퓨어'),
#  ('113011232',
#   '[TOUCH ME] USB 충전식 손난로 터치미 1800mA -스마트폰 보조배터리  충전젠더 포함/손난로/충전식손난로/충전식/USB/'),
#  ('1348032648', '자석식 장기 (MJ104)/명인랜드/바둑/체스/장난감/교구/만들기/인형'),
#  ('1268004389', '[땡큐샵]한지 전지 250매 650mm*950mm 색상랜덤발송[도매가]'),
#  ('1460428959', '[SR]시마노프로 컴팩트 텔레스코픽 3단 미니펌프'),
#  ('1645464687', '칼라자석보드 화이트우드몰딩 1100 X 1200(보드칠판)'),
#  ('1589176648', '다용도 3단 밀봉 방수팩(22cm×18cm)'),
#  ('1343424401',
#   '나이키/후드/자켓/풀집/짚업/후디/NIKE AW77 FT FZ HOODY-SHOBX/678561-891/남성용'),
#  ('1138220713', '2014테크니화이버 테니스 스트링 폴리코드1.25mm(17G)'),
#  ('22044287', '청정원 홍초 바이탈플러스 석류 500㎖ 4개/맑음몰'),
#  ('150284188', '청일상사 8자형끈/끈/포장용끈/바인더끈/적끈/적색끈/바인다끈/적끈대/동태끈/대끈/바인더끈'),
#  ('1113604509',
#   'mgS3-S5-78-연꽃 (lotus)/시즈팝/갤럭시S3-S5스킨/갤럭시S3-S5스티커/갤럭시S3/갤럭시S4/갤럭시S5/휴대폰데코'),
#  ('1449880322', '[더베스트] [ITB139]  Coms 스프링 스트랩 OD: 3.5mm, 13cm / Black'),
#  ('1668331115', '[NF80758]LP 발목보호대 세라믹 994'),
#  ('1138539903', '[마마보이야]제노바MM1602 DSLR가방 카메라가방(중) 출사 캠코더 비디오 디카 토드백 남녀공용'),
#  ('1277397731', '무료배송- 오렌지 수키 TW 068 앞일자 7cm 가죽 하이힐샌들'),
#  ('1662735369', '아이조아 개조심 (60074) 개조심게임장난감 개조심게'),
#  ('949335518', '구룡포과메기 모듬풀세트 특대 6~8인분 (포항구룡포)'),
#  ('1355974068', '기가바이트 PURE STEEL 레드 500GB 외장SSD'),
#  ('1429050955', '스테판조셉 실꿰기카드5P세트 실궤기놀이'),
#  ('1649387078', 'DL380 Gen9 (E5-2609v4 1.7GHz 8C / 8GB / 500GB)'),
#  ('1146713704', '(추천)록타이트 243 중강도 볼트 고정제 250ml/나사고정/혐기성접착제/볼트본드/나사본드/볼트'),
#  ('1133207264', '[핫트랙스] 레드 - 필웰모던스퀘어디자인의자'),
#  ('1293252538', '현풍 결재판 결재바람 윈도우창 191/결재서류/5개'),
#  ('1226391833', 'SUB 지문필름_모토글램 (XT-W800)'),
#  ('1495207877', '퍼퓸씨드 로즈 바디 미스트/ 더페이스샵'),
#  ('1611544124', '인테리어 스위치커버 그래픽스티커 파인애플 WBSS7170'),
#  ('1641348531', '핑크 스크레쳐 포스트 미니 스크래쳐'),
#  ('382623399', '[여수농협] 고들빼기김치 2kg 돌산갓김치 국내산재료 HACCP 전통우수식품 인증 산지직송'),
#  ('1673070239', '울진 아쿠아리움 입장권+음료PKG/테마파크/울진가볼만한곳/놀이동산/가족여행추천/어린이체험'),
#  ('1511249486', '[에코벨] USB 온열 마우스 패드'),
#  ('1565601521',
#   '[뉴발란스(NEW BALANCE)]남녀공용 액티브웨어 조거팬츠(NBML634013/Green) (센텀시티점)'),
#  ('1489789689',
#   '[모던피플] 8/10 banding wide pants ; lp ( 6color / free size ) 8부 밴딩 와이드 팬츠 / 남자와이드데님'),
#  ('1691641485', '공놀이 오고디스크 메조(380mm)/체육 교보재/kj'),
#  ('1378485983', '일리 토탈에이징케어 핸드크림50ml/해피바스 핸드크림'),
#  ('1227012957', '[1358k] cs101-뮤직 빌리지_글라스_글라스시트지'),
#  ('1547121108', '스마트폰현미경 WF210/무선/WIFI/WF311/안드로이드'),
#  ('1123100425', '이노비아 888/8부셔링 셔링 면스판 무지7부레깅스 내벗'),
#  ('1607918106', '무료배송 샤오미 정품 체중계/전자랜드AS센터AS가능'),
#  ('1623146830', '[신디키즈]시보리밴드본딩스키니블랙데님'),
#  ('1489420407', '노블리스 3단접이식 빨아쓰는 매트리스 멀티싱글 7cm(커버+케미칼텍스 매트)'),
#  ('1150292030', 'enzo 기어노브/기어봉'),
#  ('1508785156', '흡착형 코너용 수건걸이 SQ-1027'),
#  ('1693078657', 'DIAMOND트레싱지(A3-95g-250매X2권) 복사용품 트레싱'),
#  ('1540786735', '/향수 이터너티_200ml 애완용품 강아지용품 애견용품'),
#  ('1665914874', '거울욕조'),
#  ('1471251474', '양가죽자켓 명품재킷 투버튼가죽자켓 남성가죽마이'),
#  ('1645620884', 'XBOX ONE 키넥트 센서'),
#  ('1343426231', '컬러풀 클립보드(A4) 고객판촉용 관공서판촉용'),
#  ('1512705748', '애플 뉴맥북프로 레티나 MGX72KH/A 노트북/태블릿/악보 겸용 거치대/이동식테이블/책상'),
#  ('1606444491', '거북이 CD 케이스'),
#  ('1185093058', '수퍼 락스 15L/세제/욕실세제/살균제거제/악취제거/소독/세정제/욕실청소/청소/업소용'),
#  ('1593424471', '힐링 의자 대 의자 플라스틱의자 보조의자 회의용의자'),
#  ('1621296282', '[제이엘프]베르사유 가디건자켓/롱가디건/하프/루즈핏'),
#  ('1564935435', '반장갑 LB-130B 스포츠장갑 다용도스포츠장갑 운동장'),
#  ('1443837811', '진영감쑥뜸기2호X진영감왕쑥봉X킹터보라이터세트'),
#  ('1438720101', '정식품/유아식2단계190ml(16팩)X4박스/토들러'),
#  ('1516019662',
#   '(HG)1_144 MS옵션세트4   모빌워커 (004) 건담프라모델조립 건담프라모델 HighGHG 철혈의오르펜즈 BANDAI'),
#  ('1397267114', '[11번가몬도]뮤즈레오파트퍼코트-재입고-'),
#  ('1622619555', '네코모테 고양이가 좋아하는 마타타비 화이트마우스 ('),
#  ('1354203619', '(GM)라네즈 옴므 듀얼 액션 에센스 로션 (40ml)'),
#  ('1647566787', '[디씨팡]/티엔 수분 퐁당 크림 50ml 영양 수분 크림'),
#  ('588108288', '[판매중]타올 키친타올 순수펄프사용 토미키친타올 엠보싱 가정용 집들이 선물용 키친타올과 핸드롤 타올'),
#  ('1599164634', '애경프리미엄여행용세트1호자전거/자물쇠/다용도줄/자'),
#  ('1485100073', '[웨버] 아웃러장식 가죽줄 ST 3_4x6ST_2cmx180cm'),
#  ('1100287278', '[마이독스] 애니멀 도기토이(종류임의배송)/애견/강아지/애완/개/용품/장난감/원반/삑삑이/인형/공/볼/스포'),
#  ('1531675326', '(L)1RCA(M)-1RCA(M)케이블 10M 케이블 음성케이블 RCA'),
#  ('1656724513', '미에로화이바(초특가) 100ml/210ml/350ml/1.5L'),
#  ('1394676006', 'i1 인기상품 셀리오에센셜투웨이케익-23호 내추럴베이지 리필포함 1개 /트윈케익/vip'),
#  ('1548784868',
#   '(KANALS) BK7001N BK-7001N ENTERGRAN 무선마이크 900MHz 핸드 핀 벨트팩 1채널 / 인기상품 특가 할인 진행 중! 음향기기 전문 엠사운드몰'),
#  ('1592360360', '셀레스트론 AstroMaster 102AZ 천체망원경 초보용'),
#  ('1562252651', '머스타드 모아하우스 454g 머스터드'),
#  ('1439241691', '[중고][진보라폰]SCH-W350/SPH-W3500/JIN BORA 폰/3G폴더폰'),
#  ('1387738612', '러브스위치 워터프루프마스카라 컬링 볼륨 속눈썹연장'),
#  ('1155162483', '[인사동점] 박물관은살아있다 입장권/트릭아트 뮤지엄/당일사용/전시사진/데이트코스'),
#  ('1201572326', '무료배송-JJ매직곰팡이제거제_500ml 곰팡이코팅제 곰팡이제거제 곰팡이냄새제거 생활용품 곰팡이얼룩제거'),
#  ('1082649698', '상패 감사패 크리스탈상패 부모님감사패 SD12-20'),
#  ('1449426026', '(추천)율동방울/ 유아악기 악기장난감 어린이장난감 유아장난감 유아용품 어린이완구 유아완구 아동완구'),
#  ('1467278229', '[드라이부르크]OLD SCHOOL TOTE 올드스쿨 토트백 Br.'),
#  ('1604308098', '당일발송 유니콘 TA-100N 여행용 멀티어댑터 젠더'),
#  ('1598069900', '[로하스테크][B급 리퍼] 제우스 3D 고급형 전신안마의자 ZEUS LH-7801'),
#  ('1357013279', '골드 명합지갑(삼족오)/명함보관용지갑 남성용명함지갑 장석명함지갑 명함보관 명함용지갑'),
#  ('1599178434', '롱노즈 HL-D04(120mm 미니) KEIBA-케이바/공구몰/니퍼'),
#  ('464336620', '다인푸드 냉동 낙지 6미 850g(6팩)/냉동낙지/연포탕'),
#  ('1621222122', '카이사르오카리나알토C(모든음악선생님추천)'),
#  ('1503619241', '삼성 정품 급속 충전 스탠드형 라인에디션 EP-NG930L'),
#  ('1276408689', 'O다량구매 차등가격O 인텍스 UV차단 실리콘 물안경/잠수경/물안경/오리발/물놀이/스노클/여름캠프/바캉스/'),
#  ('1486644572', '新新아동다운자켓 구스다운 덕다운 아동패딩'),
#  ('1641229959', '마스크 방한모 겨울모자 털모자 방한용모자 겨울털모'),
#  ('1315173809', '컨투어플러스 혈당시험지 1박스(100매입) 혈당검사지'),
#  ('1216416820', '아쿠아엘 미니 UV렘프[미니 UV살균 램프]'),
#  ('1580928893', '도루코일회용프레쉬두날면도기10p 2중날 TD706 (11382'),
#  ('1651188370', '영창 오카리나 12000 오카리나 영창악기'),
#  ('1616480947', '오늘도 즐거운 냥이 놀이터 하우스 캣타워 618'),
#  ('1460586129', '숨37 화이트 어워드 모이스처 밸런싱 에멀젼'),
#  ('1542319025', '코리아나 발효녹두 깨끗한 클렌징 워터 400ml'),
#  ('1509001084', '[탑앤탑]반사 가이 로프 50(2.5mm×50m)/보조로프/다용도로프'),
#  ('1641426976', 'if 3WC 크리스탈 화이트닝 씨씨크림 1호 50ml/b'),
#  ('1432748682',
#   '스타루스 캠핑텐트 DRANGO-M 텐트 [올리브그린블랙] (L306003OB) 2~3인용/220X130X130cm'),
#  ('1607102583', '마몽드 에이지 컨트롤 파워 아이크림 (25ml)'),
#  ('1486714083', '로베아 젠틀 쉬어버터 헤어 샴푸 750ml'),
#  ('1600357106', '우토토이즈 수와셈놀이/셈놀이,우토토이즈,숫자놀이,'),
#  ('1573100224', '[더블하트 신생아용 손톱가위] 손톱 가위 유아용품'),
#  ('428990244', '커클랜드 새우(31-40마리/908G)/777000'),
#  ('1665250164',
#   '제주 소인국테마파크 + 카멜리아힐  제주도 관광지 2곳 패키지 입장권 할인 /기프트제주/제주 승마체험/제주 승마/제주승마할인/제주 승마장 추천/제주도 승마체험 가격말타는곳 말타기'),
#  ('1625324370', '[NATURE REPUBLIC]프로방스 인텐시브 앰플 비비크림 S'),
#  ('1386015002', '[닥터맘키즈] 울타리형안전문 1.4m-1.5mx높이75cm/울타리형안전문/안전문/울타리/안전가드/주문제작'),
#  ('1662819211', 'F (디비닷컴)  CK-09RK 트랙볼 미니무선키보드'),
#  ('1510274016', '에너자이저 건전지AAA(2알x20카드/1박스)/카메라/캠코더/건전지/충전지/충전기'),
#  ('1352830460', '맥데이비드 LV.2 중급 무릎보호대(4195R) SUL-CC1-25'),
#  ('1630379206',
#   '[푸마 (PUMA)][PUMA]푸마 BTSxPUMA 남녀공용 시베리아 덕 다운 FD Sporty Down Uni 897570 04 구매시 패...'),
#  ('1592452720', 'BP00820 앵무새/앵무새용품/장난감'),
#  ('1711322904', '[핫트랙스] 삼각자(잉킹) 30cm (스모키)(개)'),
#  ('1524280565', '엑셀런트 초대형 패드 20매 애견용품 배변패드 강아지위생 위생패드 애견위생용품 애완견용품'),
#  ('1404543438', '염색솔/염색그릇/헤어비닐캡/깔깔이미용장갑/귀마개/깔깔이장갑/동광깔깔이장갑'),
#  ('1147068983', '레인보우 도트 다이어리'),
#  ('1291247635', '고급 핸드카트 핸드카 쇼핑카트 401호 장바구니 시장'),
#  ('1602687202', 'SW/809767-014 파리생제르망 트레이닝팬츠/나이키팬츠'),
#  ('1351959468', '레우스 선글라스 (미러골드)'),
#  ('1153720990', '프렌베니 로라 앞치마세트 RORA/북유럽풍 아동 앞치마/에이프런/방수앞치마'),
#  ('1459509748', 'TSA 여행용 와이어 자물쇠'),
#  ('1537755926', 'World to UK with USB/영국 싱가폴 홍콩 말레이지아'),
#  ('1169384952', '[라잇에이드][라잇에이드] 일회용 수유패드 3개 세트[갤러리아]'),
#  ('1409332684', '[분당종합피아노] 카시오 디지털피아노 CDP-230R'),
#  ('1354322984', '[에센바흐] 독일 지갑형 돋보기 1752560 - 3.5배,크기60mm'),
#  ('158105819', '[G7566] 우퍼 스피커 (FS-8000 Q10)'),
#  ('1543392376', '[오디스샵] 태양열 핸드폰 진열대 핸드폰전시 회전진열대'),
#  ('1662999393', '근태관리기 EF-006KC 지문 카드 비밀번호인식 네트워'),
#  ('1708913385', '[GRET](발리)래프팅 + 끄라파디너 포함 데이프로그램'),
#  ('1038388344',
#   '[무료배송][할인특가] 1/35 SD KFZ 10/5 and2CM FLAK 38 밀리터리 탱크 기억남는 선물sns모바일'),
#  ('1466392605', '(HP) KEY RING V285W 8GB /USB용품 /USB용품'),
#  ('97256817', '맥베이커리 - 찰보리찜케이크'),
#  ('1601167949', '(동영상) La Ferrari RTR RC (SVL86078RE) 라페라리'),
#  ('1264301433',
#   '[중고][오에이존][불량제품]HP 오피스젯 6500A Special Edition 잉크젯복합기(인쇄+복사+스캔+팩스)/기기만판매'),
#  ('1477702262', '[버드시아] 쿠션 아기의자 전용 식판(버드시아 정품 호환)'),
#  ('1225165758',
#   "초특가▶ 세이프 리어 립 스포일러 NF YF 쏘나타 소나타 09' 뉴SM3 그랜져HG 제네시스 세단 크레도스"),
#  ('1618047845', '(AGCPKT 방한 귀마개 모자 캡 TYC1512 방한모 귀마개'),
#  ('1688841020', '푸쉬핀 No.12 22mm 20개 사무용고정핀 고정핀 고정용'),
#  ('1535878437', '소울시계 CG6099b 남녀패션시계 남녀커플시계 남녀손'),
#  ('1373277154', '[헤라(HERA)]옴므 레포츠 선크림 SPF50+/PA+++ (50ml)'),
#  ('1368236874', '집중모객   주말출도착  서유럽 핵심 4국 8일  프랑스 스위스 이태리 독일'),
#  ('1468173466', '다목적 이액형 에폭시 접착제 EP-04 접착제 에폭시본드 엑시아 이액형에폭시 에폭시접착제 금속접착제'),
#  ('1405158509', '라이플 LIFUL/정품/신상/320/크로스백/가방/숄더백/가방/캐주얼 가방/무료배송'),
#  ('1553121374', '바하 트럼펫 Bach_LR180S37'),
#  ('1582677798', '화분백화점 퇴비 비료 영양제 선그린(3kg)'),
#  ('1663845800', '[BC카드10%][방콕] 한 헤리티지 스파 E바우처 한 헤리티지-120분+페이셜'),
#  ('1702011058', '[BC카드10%][대만] 스프링시티 노천 온천 E바우처 -'),
#  ('1558481599', '[와우] 은나노물티슈_80매(캡형)'),
#  ('1599909100', '[솔로예찬] 대만 자유여행 2박3일 - 싱글족 전용'),
#  ('1609827866', '직사각물받이화분받침 2호 받침대 화분다이 화분선반'),
#  ('1668661588', 'LG 하우시스 친환경데코타일 3T우드비점착 WBDBW3030A'),
#  ('1604415261', '사파이어 절전형 미니 라디에이터 5핀 HJO-M05'),
#  ('1579183166', '2절칼라우드락5T/2절칼라보드/C41.형광연두600×900'),
#  ('1421978676', '[후추통][꿈비][미미루] 빈백소파 드몽 - 유아용소파/빈백/소파/완구/미미루/드몽/가구/유아동가구/소파/'),
#  ('1437325597',
#   '도매특가/중외 섬유 발수 코팅제 CW-6030J 350ml/캠핑용품 발수제 등산용품 도매 판촉 기업 학교 관공서 대'),
#  ('1663020910', '[친환경 편백아트]편백나무 원적외선 옥 반신욕기 [적삼목 + 원적외선 + 옥 +'),
#  ('1552940047', '[하프클럽/campingstory]앙쥬르버블티슈5매아기샤워목욕퓨어인터네셔날'),
#  ('1367386936', '실속만 쏙 쏙  홍콩 일급  2박3일'),
#  ('1653509782', '쥴스 데스트루퍼 비스킷 650g/ 글로벌푸드'),
#  ('1642271140', '[보리보리/아트박스 POOM(문구,팬시)#]제이로그 특별한 하루 데코팩(스티커+코너스티커+수납케이스)'),
#  ('1482130577',
#   '(C)아이폰5 케이블(Flat) Blue. 2M 애플 라이트닝 8핀 USB 플랫케이블 평면케이블 플랫케이블 스마트폰연결잭 연결잭 다용도케이블 휴대용케이블'),
#  ('1215572170', '빠름배송요리가 즐거워지는 스틸 계량스푼 계량용품 요리도구 조리도구 계량스푼 주방용품'),
#  ('1560057765', '바이크존 / XCB7201 / [바이크닉] BZ통바지'),
#  ('1160329226', '얼룩말스카프-미니/롱/쉬폰/사각/명품/파시미나'),
#  ('1592626045', '[아트박스 POOM/바이빔] 쁘띠6등 샹들리에-화이트'),
#  ('1482599549', '갤럭시코어세이프 스마트폰/차량용 오디오 스프링 AUX 케이블'),
#  ('1217686352', '익소몰[8360388-명신광학]원렌즈 안전안경/J-30A/케이스 有/(1EA)/안전안경/보안경/안전고글'),
#  ('1154948801', '보안경 3M 40654 고글형보안경 Anti-Fog  회전 머리끈'),
#  ('1666310496', '25Pin MF공유기 케이블 5M(BLC2414) PC용품 컴퓨터용'),
#  ('1594044691', '오버니삭스/예쁜핏/패션리더/무료배송'),
#  ('1615390857', '패리스독 캐릭터 모자 - 베어(베이지) 강아지귀마재'),
#  ('1099230480',
#   '(추천) [또봇 구명조끼 30KG(TB-14V30] 유아구명조끼 어린이구명조끼 아동구명조끼 유아용구명조끼 아기구'),
#  ('1627699817', '쓰리엔에스(3NS)텍스 근육테이프v(살색)x 1개'),
#  ('1665590868', '가정용 업소용 망사 선풍기 안전망 선풍기 여름 안전'),
#  ('1576284747', 'MCN스포츠-라우다 반팔 져지/라이딩반팔/자전거복장'),
#  ('1539376581', '45 -70 일반형 LCD 거치대 티비 벽걸이 브라켓 TV거치'),
#  ('1463263370', '055-980-8181 김해M컨벤션웨딩홀 웨딩홀 결혼축하화환d12 김해웨딩화환 근처꽃아쿠아eu'),
#  ...]

# %%
len(X_test_noun)
# Out:
# 1700

# %%
len(img_feature_list)
# Out:
# 6800

# %%
len(img_feature_test_list)
# Out:
# 1700

# %% [markdown]
# #### 아래 부분은 text feature 와 이미지 feature 를 합쳐서 feature 를 만드는 부분이다. 이 부분에 대해서는 각자 한번 합치는 방법을 찾아 보면 된다.

# %%
concat_x_list = sparse.hstack((vectorizer.transform(X_train_noun), img_feature_list))
concat_test_x_list = sparse.hstack((vectorizer.transform(X_test_noun), img_feature_test_list))

# %%
len(img_feature_list + img_feature_test_list) # 8092
len(X_train_noun + X_test_noun) # 8500
# Out:
# 8500

# %%
concat_x_all_list = sparse.hstack((vectorizer.transform(X_train_noun + X_test_noun), img_feature_list + img_feature_test_list))

# %%
for k in range(1, 10):
    c = 0.05 + (k / 200)
    clf2 = LinearSVC(C=c)
    clf2.fit(concat_x_list, y_train)
    print (c,clf2.score(concat_test_x_list, y_test))
# Out:
# 0.055 0.713529411765
# 0.060000000000000005 0.713529411765
# 0.065 0.712941176471
# 0.07 0.709411764706
# 0.07500000000000001 0.707058823529
# 0.08 0.707647058824
# 0.085 0.705882352941
# 0.09 0.705294117647
# 0.095 0.704705882353

# %%
c = 0.06
clf2 = LinearSVC(C=c)
clf2.fit(concat_x_all_list, y_train + y_test)
print (c,clf2.score(concat_test_x_list, y_test))
# Out:
# 0.06 0.981764705882

# %%
del pid_img_feature_dict

# %% [markdown]
# ### CNN 피쳐를 추가 해서 분류후 평가 서버에 분류 결과를 전송

# %%
pid_img_feature_dict = {}
with open("refined_category_dataset.img_feature.eval.dat") as fin:
    for idx,line in enumerate(fin):
        if idx%100 == 0:
            print(idx)
        pid, img_feature_str = line.strip().split(" ")
        img_feature = (np.asarray(list(map(lambda i : float(i),img_feature_str.split(",")))))
        pid_img_feature_dict[pid] = img_feature
#         print (line)
#         break
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500

# %%
real_test_x_text_list = []
with open("soma8_test_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        real_test_x_text_list.append((info['pid'],info['name']))

# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
img_feature_test_list = []

# %%
for pid, name in real_test_x_text_list:
    if pid in pid_img_feature_dict:
        img_feature_test_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_test_list.append(np.zeros(1000))

# %%
print (len(img_feature_test_list), len(real_test_x_text_list))
# Out:
# 1292 1292

# %%
X_real_test_noun = extract(real_test_x_text_list)

# %%
x_feature_list = vectorizer.transform(X_real_test_noun)

# %% [markdown]
# #### 2개 feature 를 합치는 방법 찾아보기

# %%
concat_real_test_x_list = sparse.hstack((x_feature_list, img_feature_test_list),format='csr')

# %%
pred_list = clf2.predict(concat_real_test_x_list)

# %%
import requests
name='홍상원'
nickname='Frodo_'
mode='test'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
print (d.json())
# Out:
# {'msg': 'If you pull docker image before 2017-09-27 21:30,  pull your docker image again.', 'precision': 0.7407120743034056}

# %%
eval_x_text_list = []
with open("soma8_eval_data.dat",encoding=enc) as fin:
    for line in fin.readlines():
        info = json.loads(line.strip())
        eval_x_text_list.append((info['pid'],info['name']))

# pred_list = clf.predict(vectorizer.transform(map(lambda i : i[1],eval_x_text_list)))

# %%
img_feature_eval_list = []
for pid, name in eval_x_text_list:
    if pid in pid_img_feature_dict:
        img_feature_eval_list.append(pid_img_feature_dict[pid])
    else:
        img_feature_eval_list.append(np.zeros(1000))

# %%
x_feature_list = vectorizer.transform(extract(eval_x_text_list))

# %%
concat_eval_x_list = sparse.hstack((x_feature_list, img_feature_eval_list),format='csr')

# %%
pred_list = clf2.predict(concat_eval_x_list)

# %%
import requests
name='홍 상원'
nickname='Frodo_'
mode='eval'
param = {'pred_list':",".join(map(lambda i : str(int(i)),pred_list.tolist())),
         'name':name,'nickname':nickname,'mode':mode}
d = requests.post('http://eval.buzzni.net:20001/eval',data=param)
print (d.json())
